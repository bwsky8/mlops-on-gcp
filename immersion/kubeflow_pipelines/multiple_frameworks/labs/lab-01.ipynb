# %% [markdown]
# ## Lab: Continuous Training with TensorFlow, PyTorch, XGBoost, and Scikit-learn Models with KubeFlow and AI Platform Pipelines
#
# In this lab we will create containerized training applications for ML models in TensorFlow, PyTorch, XGBoost, and Scikit-learn. Will will then use these images as ops in a KubeFlow pipeline and train multiple models in parallel. We will then set up recurring runs of our KubeFlow pipeline in the UI.
#
# First, we will containerize models in TF, PyTorch, XGBoost and Scikit-learn following a step-wise process for each:
# * Create the training script
# * Package training script into a Docker Image
# * Build and push training image to Google Cloud Container Registry
#
# Once we have all four training images built and pushed to the Container Registry, we will build a KubeFlow pipeline that does two things:
# * Queries BigQuery to create training/validation splits and export results as sharded CSV files in GCS
# * Launches AI Platform training jobs with our four containerized training applications, using the exported CSV data as input
#
# Finally, we will compile and deploy our pipeline. In the UI we will set up Continuous Training with recurring pipeline runs.
#
# **PRIOR TO STARTING THE LAB:** Make sure you create a new instance with AI Platform Pipelines. Once the GKE cluster is spun up, copy the endpoint because you will need it in this lab.

# %% [markdown]
# Start by setting some global variables. Make sure you have created a bucket that is gs://PROJECT_ID

# %%
REGION = 'us-central1'
PROJECT_ID = !(gcloud config get-value core/project)
PROJECT_ID = PROJECT_ID[0]
BUCKET = 'gs://' + PROJECT_ID

# %% [markdown]
# First, create a BigQuery dataset. We will then query a public BigQuery dataset to populate a table in this dataset. This is census data. We will use age, workclass, education, occupation, and hours per week to predict income bracket. Note: We also grab functional_weight in our query. We do not use this feature in our models, however we use it to hash on when creating training/validation splits.

# %%
# !bq --location=US mk census
# Out:
# BigQuery error in mk operation: Dataset 'qwiklabs-gcp-04-248da7eb1719:census'
# already exists.

# %%
# %%bigquery
#
# CREATE OR REPLACE TABLE census.data AS
#
# SELECT age, workclass, education_num, occupation, hours_per_week,income_bracket,functional_weight
# FROM `bigquery-public-data.ml_datasets.census_adult_income`
# WHERE AGE IS NOT NULL
# AND workclass IS NOT NULL
# AND education_num IS NOT NULL
# AND occupation IS NOT NULL
# AND hours_per_week IS NOT NULL
# AND income_bracket IS NOT NULL
# AND functional_weight IS NOT NULL
# Out:
# Query complete after 0.01s: 100%|██████████| 3/3 [00:00<00:00, 1838.80query/s]
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Create Scikit-learn Training Script
#
# We will develop our first training script with Scikit-learn. We will use Pandas to read the CSV data then train a simple [SGD Classifier](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html).

# %%
# !mkdir scikit_trainer_image
# Out:
# mkdir: cannot create directory ‘scikit_trainer_image’: File exists

# %%
# %%writefile ./scikit_trainer_image/train.py

"""Census Scikit-learn classifier trainer script."""

import pickle
import subprocess
import sys
import datetime
import os

import fire
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler


def train_evaluate(training_dataset_path, validation_dataset_path,output_dir):
    """Trains the Census Classifier model."""
    
    # Ingest data into Pandas Dataframes 
    df_train = pd.read_csv(training_dataset_path)
    df_validation = pd.read_csv(validation_dataset_path)
    df_train = pd.concat([df_train, df_validation])
    
    numeric_features = [
        'age', 'education_num','hours_per_week'
    ]
    
    categorical_features = ['workclass', 'occupation']
    
    # Scale numeric features, one-hot encode categorical features
    preprocessor = ColumnTransformer(transformers=[(
        'num', StandardScaler(),
        numeric_features),
        ('cat', OneHotEncoder(), categorical_features)])
    
    pipeline = Pipeline([('preprocessor', preprocessor),
                         ('classifier', SGDClassifier(loss='log'))])
    
    num_features_type_map = {feature: 'float64' for feature in numeric_features}
    df_train = df_train.astype(num_features_type_map)
    df_validation = df_validation.astype(num_features_type_map)
    
    X_train = df_train.drop('income_bracket', axis=1)
    y_train = df_train['income_bracket']
    
    # Set parameters of the model and fit
    pipeline.set_params(classifier__alpha=0.0005, classifier__max_iter=250)
    pipeline.fit(X_train, y_train)
    
    # Save the model locally
    model_filename = 'model.pkl'
    with open(model_filename, 'wb') as model_file:
        pickle.dump(pipeline, model_file)
        
    # Copy to model to GCS 
    EXPORT_PATH = os.path.join(
        output_dir, datetime.datetime.now().strftime("%Y%m%d%H%M%S"))
    
    gcs_model_path = '{}/{}'.format(EXPORT_PATH, model_filename)
    subprocess.check_call(['gsutil', 'cp', model_filename, gcs_model_path])
    print('Saved model in: {}'.format(gcs_model_path))


if __name__ == '__main__':
    fire.Fire(train_evaluate)
# Out:
# Overwriting ./scikit_trainer_image/train.py

# %% [markdown]
# ### Package Scikit-learn Training Script into a Docker Image
# The next step is to package this training script into a Docker Image. We need to be sure to list the dependencies in this Dockerfile. For the Scikit-learn model we need to ensure scikit-learn version 0.23.2 and Pandas version 1.1.1

# %%
# %%writefile ./scikit_trainer_image/Dockerfile
#
# FROM gcr.io/deeplearning-platform-release/base-cpu
# RUN pip install -U fire scikit-learn==0.23.2 pandas==1.1.1
# WORKDIR /app
# COPY train.py .
#
# ENTRYPOINT ["python", "train.py"]
# Out:
# Overwriting ./scikit_trainer_image/Dockerfile

# %% [markdown]
# ### Build the scikit-learn trainer image
#
# Now we will use Cloud Build to build the image and push it your project's Container Registry. Here we are using the remote cloud service to build the image, so we don't need a local installation of Docker. Note: Building and pushing the image will take a few minutes. Since we will be building and pushing 4 different images in this lab, I suggest taking a detailed look at the training scripts while you wait and make sure you understand the data ingestion/model building/training code for frameworks you develop with.

# %%
SCIKIT_IMAGE_NAME='scikit_trainer_image'
SCIKIT_IMAGE_TAG='latest'
SCIKIT_IMAGE_URI='gcr.io/{}/{}:{}'.format(PROJECT_ID, SCIKIT_IMAGE_NAME, SCIKIT_IMAGE_TAG)

# %%
# !gcloud builds submit --tag $SCIKIT_IMAGE_URI $SCIKIT_IMAGE_NAME
# Out:
# Creating temporary tarball archive of 2 file(s) totalling 2.4 KiB before compression.
# Uploading tarball of [scikit_trainer_image] to [gs://qwiklabs-gcp-04-248da7eb1719_cloudbuild/source/1620009050.515337-ad7121fdb2a94283b0976fbe8908b401.tgz]
# Created [https://cloudbuild.googleapis.com/v1/projects/qwiklabs-gcp-04-248da7eb1719/locations/global/builds/a74b99ee-b36c-438d-ae76-957e17f1f65d].
# Logs are available at [https://console.cloud.google.com/cloud-build/builds/a74b99ee-b36c-438d-ae76-957e17f1f65d?project=551343526661].
# ----------------------------- REMOTE BUILD OUTPUT ------------------------------
# starting build "a74b99ee-b36c-438d-ae76-957e17f1f65d"
#
# FETCHSOURCE
# Fetching storage object: gs://qwiklabs-gcp-04-248da7eb1719_cloudbuild/source/1620009050.515337-ad7121fdb2a94283b0976fbe8908b401.tgz#1620009050752861
# Copying gs://qwiklabs-gcp-04-248da7eb1719_cloudbuild/source/1620009050.515337-ad7121fdb2a94283b0976fbe8908b401.tgz#1620009050752861...
# / [1 files][  1.2 KiB/  1.2 KiB]
# Operation completed over 1 objects/1.2 KiB.
# BUILD
# Already have image (with digest): gcr.io/cloud-builders/docker
# Sending build context to Docker daemon   5.12kB
# Step 1/5 : FROM gcr.io/deeplearning-platform-release/base-cpu
# latest: Pulling from deeplearning-platform-release/base-cpu
# 6e0aa5e7af40: Pulling fs layer
# d47239a868b3: Pulling fs layer
# 49cbb10cca85: Pulling fs layer
# 111e3a13fbd4: Pulling fs layer
# b35c22f6a9bc: Pulling fs layer
# 8206ae2b86e3: Pulling fs layer
# 4f4fb700ef54: Pulling fs layer
# a9b2fba996c8: Pulling fs layer
# 57c8f95170d4: Pulling fs layer
# 217c82b1f15a: Pulling fs layer
# 973cc805e91c: Pulling fs layer
# c425ab4c2c48: Pulling fs layer
# aed13e0eac71: Pulling fs layer
# 8af440fcd8dd: Pulling fs layer
# dd95c6ad22f2: Pulling fs layer
# 4e6c4135d19b: Pulling fs layer
# 3d9b09ca1e5d: Pulling fs layer
# 2a6cb8fdb8cf: Pulling fs layer
# 9dd554f1f284: Pulling fs layer
# 111e3a13fbd4: Waiting
# b35c22f6a9bc: Waiting
# 973cc805e91c: Waiting
# 8206ae2b86e3: Waiting
# c425ab4c2c48: Waiting
# aed13e0eac71: Waiting
# 4f4fb700ef54: Waiting
# 8af440fcd8dd: Waiting
# a9b2fba996c8: Waiting
# dd95c6ad22f2: Waiting
# 57c8f95170d4: Waiting
# 4e6c4135d19b: Waiting
# 217c82b1f15a: Waiting
# 3d9b09ca1e5d: Waiting
# 2a6cb8fdb8cf: Waiting
# 9dd554f1f284: Waiting
# d47239a868b3: Verifying Checksum
# d47239a868b3: Download complete
# 49cbb10cca85: Verifying Checksum
# 49cbb10cca85: Download complete
# 111e3a13fbd4: Download complete
# 6e0aa5e7af40: Verifying Checksum
# 6e0aa5e7af40: Download complete
# 4f4fb700ef54: Verifying Checksum
# 4f4fb700ef54: Download complete
# a9b2fba996c8: Verifying Checksum
# a9b2fba996c8: Download complete
# 8206ae2b86e3: Verifying Checksum
# 8206ae2b86e3: Download complete
# 217c82b1f15a: Verifying Checksum
# 217c82b1f15a: Download complete
# 973cc805e91c: Verifying Checksum
# 973cc805e91c: Download complete
# c425ab4c2c48: Verifying Checksum
# c425ab4c2c48: Download complete
# aed13e0eac71: Verifying Checksum
# aed13e0eac71: Download complete
# 8af440fcd8dd: Verifying Checksum
# 8af440fcd8dd: Download complete
# dd95c6ad22f2: Verifying Checksum
# dd95c6ad22f2: Download complete
# 4e6c4135d19b: Verifying Checksum
# 4e6c4135d19b: Download complete
# 3d9b09ca1e5d: Verifying Checksum
# 3d9b09ca1e5d: Download complete
# 57c8f95170d4: Verifying Checksum
# 57c8f95170d4: Download complete
# 9dd554f1f284: Verifying Checksum
# 9dd554f1f284: Download complete
# b35c22f6a9bc: Verifying Checksum
# b35c22f6a9bc: Download complete
# 6e0aa5e7af40: Pull complete
# d47239a868b3: Pull complete
# 49cbb10cca85: Pull complete
# 111e3a13fbd4: Pull complete
# 2a6cb8fdb8cf: Verifying Checksum
# 2a6cb8fdb8cf: Download complete
# b35c22f6a9bc: Pull complete
# 8206ae2b86e3: Pull complete
# 4f4fb700ef54: Pull complete
# a9b2fba996c8: Pull complete
# 57c8f95170d4: Pull complete
# 217c82b1f15a: Pull complete
# 973cc805e91c: Pull complete
# c425ab4c2c48: Pull complete
# aed13e0eac71: Pull complete
# 8af440fcd8dd: Pull complete
# dd95c6ad22f2: Pull complete
# 4e6c4135d19b: Pull complete
# 3d9b09ca1e5d: Pull complete
# 2a6cb8fdb8cf: Pull complete
# 9dd554f1f284: Pull complete
# Digest: sha256:8d72ecc97cd91b32cfc713ee0613d2cb73aff82c0f53abdd236ba24ec7b7e76c
# Status: Downloaded newer image for gcr.io/deeplearning-platform-release/base-cpu:latest
#  ---> 257fdd9e048b
# Step 2/5 : RUN pip install -U fire scikit-learn==0.23.2 pandas==1.1.1
#  ---> Running in ff929d3eb257
# Collecting fire
#   Downloading fire-0.4.0.tar.gz (87 kB)
# Collecting scikit-learn==0.23.2
#   Downloading scikit_learn-0.23.2-cp37-cp37m-manylinux1_x86_64.whl (6.8 MB)
# Collecting pandas==1.1.1
#   Downloading pandas-1.1.1-cp37-cp37m-manylinux1_x86_64.whl (10.5 MB)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.7/site-packages (from pandas==1.1.1) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas==1.1.1) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in /opt/conda/lib/python3.7/site-packages (from pandas==1.1.1) (1.19.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn==0.23.2) (2.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /opt/conda/lib/python3.7/site-packages (from scikit-learn==0.23.2) (1.6.2)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from scikit-learn==0.23.2) (1.0.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas==1.1.1) (1.15.0)
# Collecting termcolor
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Building wheels for collected packages: fire, termcolor
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115928 sha256=87eb8a93805486e6023fca72c588e069124e044115f7f6bb1b69b5207e4436fb
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4829 sha256=a756c0f116541dae7bba44c2f3e4e65da34ca61c8856bdd54b1ef5037b4067e3
#   Stored in directory: /root/.cache/pip/wheels/3f/e3/ec/8a8336ff196023622fbcb36de0c5a5c218cbb24111d1d4c7f2
# Successfully built fire termcolor
# Installing collected packages: termcolor, scikit-learn, pandas, fire
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.1
#     Uninstalling scikit-learn-0.24.1:
#       Successfully uninstalled scikit-learn-0.24.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.2.4
#     Uninstalling pandas-1.2.4:
#       Successfully uninstalled pandas-1.2.4
# Successfully installed fire-0.4.0 pandas-1.1.1 scikit-learn-0.23.2 termcolor-1.1.0
# Removing intermediate container ff929d3eb257
#  ---> d9b40aa4d1d6
# Step 3/5 : WORKDIR /app
#  ---> Running in fdece2f43a29
# Removing intermediate container fdece2f43a29
#  ---> 6e49c7cc25e6
# Step 4/5 : COPY train.py .
#  ---> 272abf749993
# Step 5/5 : ENTRYPOINT ["python", "train.py"]
#  ---> Running in 9fe28cf5c5f9
# Removing intermediate container 9fe28cf5c5f9
#  ---> 47e34f40c54a
# Successfully built 47e34f40c54a
# Successfully tagged gcr.io/qwiklabs-gcp-04-248da7eb1719/scikit_trainer_image:latest
# PUSH
# Pushing gcr.io/qwiklabs-gcp-04-248da7eb1719/scikit_trainer_image:latest
# The push refers to repository [gcr.io/qwiklabs-gcp-04-248da7eb1719/scikit_trainer_image]
# 233900eb6f66: Preparing
# fb2dde79ea13: Preparing
# f67bc782bc1e: Preparing
# 06d47dc1550f: Preparing
# 6d0460e7b91d: Preparing
# 37a8adb4fafb: Preparing
# 25eacd11cb14: Preparing
# 8bc9ffacd92c: Preparing
# 640b32ec2e81: Preparing
# a803e99a9e4f: Preparing
# 6fd6ff343521: Preparing
# 889232675b1d: Preparing
# 037b4e8512b6: Preparing
# 15d726558b56: Preparing
# 1f2e24bbaee1: Preparing
# 5f70bf18a086: Preparing
# 31152d177e09: Preparing
# 3cec1b907843: Preparing
# dcc1b8729dd0: Preparing
# 6f15325cc380: Preparing
# 1e77dd81f9fa: Preparing
# 030309cad0ba: Preparing
# 889232675b1d: Waiting
# 037b4e8512b6: Waiting
# 37a8adb4fafb: Waiting
# 15d726558b56: Waiting
# 25eacd11cb14: Waiting
# 8bc9ffacd92c: Waiting
# 1f2e24bbaee1: Waiting
# 5f70bf18a086: Waiting
# 640b32ec2e81: Waiting
# a803e99a9e4f: Waiting
# 31152d177e09: Waiting
# 3cec1b907843: Waiting
# 6fd6ff343521: Waiting
# dcc1b8729dd0: Waiting
# 6f15325cc380: Waiting
# 030309cad0ba: Waiting
# 1e77dd81f9fa: Waiting
# 6d0460e7b91d: Layer already exists
# 06d47dc1550f: Layer already exists
# 37a8adb4fafb: Layer already exists
# 25eacd11cb14: Layer already exists
# 8bc9ffacd92c: Layer already exists
# 640b32ec2e81: Layer already exists
# 6fd6ff343521: Layer already exists
# a803e99a9e4f: Layer already exists
# 889232675b1d: Layer already exists
# 037b4e8512b6: Layer already exists
# 1f2e24bbaee1: Layer already exists
# 15d726558b56: Layer already exists
# 5f70bf18a086: Layer already exists
# 31152d177e09: Layer already exists
# 3cec1b907843: Layer already exists
# dcc1b8729dd0: Layer already exists
# 6f15325cc380: Layer already exists
# 1e77dd81f9fa: Layer already exists
# 030309cad0ba: Layer already exists
# 233900eb6f66: Pushed
# fb2dde79ea13: Pushed
# f67bc782bc1e: Pushed
# latest: digest: sha256:4bce10f95c0b26b040e4c51d5b81886d539986b3624a3b689767e5cbc0ed693b size: 4914
# DONE
# --------------------------------------------------------------------------------
#
# ID                                    CREATE_TIME                DURATION  SOURCE                                                                                                      IMAGES                                                              STATUS
# a74b99ee-b36c-438d-ae76-957e17f1f65d  2021-05-03T02:30:50+00:00  2M25S     gs://qwiklabs-gcp-04-248da7eb1719_cloudbuild/source/1620009050.515337-ad7121fdb2a94283b0976fbe8908b401.tgz  gcr.io/qwiklabs-gcp-04-248da7eb1719/scikit_trainer_image (+1 more)  SUCCESS

# %% [markdown]
# ### Create TensorFlow Training Script
# One down, three to go! Now we will develop a TensorFlow training script. We will use the tf.data API to ingest the data from CSVs then build/train a neural network with the tf.keras Functional API.

# %%
# !mkdir tensorflow_trainer_image
# Out:
# mkdir: cannot create directory ‘tensorflow_trainer_image’: File exists

# %%
# %%writefile ./tensorflow_trainer_image/train.py

"""Census Tensorflow classifier trainer script."""

import pickle
import subprocess
import sys
import fire
import pandas as pd
import tensorflow as tf
import datetime
import os

CSV_COLUMNS = ["age",
               "workclass",
               "education_num",
               "occupation",
               "hours_per_week",
               "income_bracket"]

# Add string name for label column
LABEL_COLUMN = "income_bracket"

# Set default values for each CSV column as a list of lists.
# Treat is_male and plurality as strings.
DEFAULTS = [[18], ["?"], [4], ["?"], [20],["<=50K"]]

def features_and_labels(row_data):
    cols = tf.io.decode_csv(row_data, record_defaults=DEFAULTS)
    feats = {
        'age': tf.reshape(cols[0], [1,]),
        'workclass': tf.reshape(cols[1],[1,]),
        'education_num': tf.reshape(cols[2],[1,]),
        'occupation': tf.reshape(cols[3],[1,]),
        'hours_per_week': tf.reshape(cols[4],[1,]),
        'income_bracket': cols[5]
    }
    label = feats.pop('income_bracket')
    label_int = tf.case([(tf.math.equal(label,tf.constant([' <=50K'])), lambda: 0),
                        (tf.math.equal(label,tf.constant([' >50K'])), lambda: 1)])
    
    return feats, label_int

def load_dataset(pattern, batch_size=1, mode='eval'):
    # Make a CSV dataset
    filelist = tf.io.gfile.glob(pattern)
    dataset = tf.data.TextLineDataset(filelist).skip(1)
    dataset = dataset.map(features_and_labels)

    # Shuffle and repeat for training
    if mode == 'train':
        dataset = dataset.shuffle(buffer_size=10*batch_size).batch(batch_size).repeat()
    else:
        dataset = dataset.batch(10)

    return dataset

def train_evaluate(training_dataset_path, validation_dataset_path, batch_size, num_train_examples, num_evals, output_dir):
    inputs = {
        'age': tf.keras.layers.Input(name='age',shape=[None],dtype='int32'),
        'workclass': tf.keras.layers.Input(name='workclass',shape=[None],dtype='string'),
        'education_num': tf.keras.layers.Input(name='education_num',shape=[None],dtype='int32'),
        'occupation': tf.keras.layers.Input(name='occupation',shape=[None],dtype='string'),
        'hours_per_week': tf.keras.layers.Input(name='hours_per_week',shape=[None],dtype='int32')
    }
    
    batch_size = int(batch_size)
    num_train_examples = int(num_train_examples)
    num_evals = int(num_evals)
    
    feat_cols = {
        'age': tf.feature_column.numeric_column('age'),
        'workclass': tf.feature_column.indicator_column(
            tf.feature_column.categorical_column_with_hash_bucket(
                key='workclass', hash_bucket_size=100
            )
        ),
        'education_num': tf.feature_column.numeric_column('education_num'),
        'occupation': tf.feature_column.indicator_column(
            tf.feature_column.categorical_column_with_hash_bucket(
                key='occupation', hash_bucket_size=100
            )
        ),
        'hours_per_week': tf.feature_column.numeric_column('hours_per_week')
    }
    
    dnn_inputs = tf.keras.layers.DenseFeatures(
        feature_columns=feat_cols.values())(inputs)
    h1 = tf.keras.layers.Dense(64, activation='relu')(dnn_inputs)
    h2 = tf.keras.layers.Dense(128, activation='relu')(h1)
    h3 = tf.keras.layers.Dense(64, activation='relu')(h2)
    output = tf.keras.layers.Dense(1, activation='sigmoid')(h3)
    
    model = tf.keras.models.Model(inputs=inputs,outputs=output)
    model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
    
    trainds = load_dataset(
        pattern=training_dataset_path,
        batch_size=batch_size,
        mode='train')
    
    evalds = load_dataset(
        pattern=validation_dataset_path,
        mode='eval')
    
    
    steps_per_epoch = num_train_examples // (batch_size * num_evals)
    
    history = model.fit(
        trainds,
        validation_data=evalds,
        validation_steps=100,
        epochs=num_evals,
        steps_per_epoch=steps_per_epoch
    )
    
    EXPORT_PATH = os.path.join(
    output_dir, datetime.datetime.now().strftime("%Y%m%d%H%M%S"))
    tf.saved_model.save(
        obj=model, export_dir=EXPORT_PATH)  # with default serving function
    
    print("Exported trained model to {}".format(EXPORT_PATH))
    
if __name__ == '__main__':
    fire.Fire(train_evaluate)
# Out:
# Overwriting ./tensorflow_trainer_image/train.py

# %% [markdown]
# ### Package TensorFlow Training Script into a Docker Image (TODO in this cell block)
# Note that the dependencies in this Dockerfile are different than for the Scikit-learn one.

# %%
# %%writefile ./tensorflow_trainer_image/Dockerfile
#
# FROM gcr.io/deeplearning-platform-release/base-cpu
# RUN pip install -U fire tensorflow==2.1.1
# WORKDIR /app
# COPY train.py .
#
# ENTRYPOINT ["python", "train.py"]
# Out:
# Overwriting ./tensorflow_trainer_image/Dockerfile

# %% [markdown]
# ### Build the Tensorflow Trainer Image
# Build the image and push it to your project's container registry. Again, this will take a few minutes.

# %%
TF_IMAGE_NAME='tensorflow_trainer_image'
TF_IMAGE_TAG='latest'
TF_IMAGE_URI='gcr.io/{}/{}:{}'.format(PROJECT_ID, TF_IMAGE_NAME, TF_IMAGE_TAG)

# %%
# !gcloud builds submit --tag $TF_IMAGE_URI $TF_IMAGE_NAME
# Out:
# Creating temporary tarball archive of 2 file(s) totalling 4.4 KiB before compression.
# Uploading tarball of [tensorflow_trainer_image] to [gs://qwiklabs-gcp-04-248da7eb1719_cloudbuild/source/1620009200.269482-7082fba132be48568b3d281f83441400.tgz]
# Created [https://cloudbuild.googleapis.com/v1/projects/qwiklabs-gcp-04-248da7eb1719/locations/global/builds/06997035-b98f-4bbb-99b4-f40f4f6757d3].
# Logs are available at [https://console.cloud.google.com/cloud-build/builds/06997035-b98f-4bbb-99b4-f40f4f6757d3?project=551343526661].
# ----------------------------- REMOTE BUILD OUTPUT ------------------------------
# starting build "06997035-b98f-4bbb-99b4-f40f4f6757d3"
#
# FETCHSOURCE
# Fetching storage object: gs://qwiklabs-gcp-04-248da7eb1719_cloudbuild/source/1620009200.269482-7082fba132be48568b3d281f83441400.tgz#1620009200508012
# Copying gs://qwiklabs-gcp-04-248da7eb1719_cloudbuild/source/1620009200.269482-7082fba132be48568b3d281f83441400.tgz#1620009200508012...
# / [1 files][  1.7 KiB/  1.7 KiB]
# Operation completed over 1 objects/1.7 KiB.
# BUILD
# Already have image (with digest): gcr.io/cloud-builders/docker
# Sending build context to Docker daemon  7.168kB
# Step 1/5 : FROM gcr.io/deeplearning-platform-release/base-cpu
# latest: Pulling from deeplearning-platform-release/base-cpu
# 6e0aa5e7af40: Pulling fs layer
# d47239a868b3: Pulling fs layer
# 49cbb10cca85: Pulling fs layer
# 111e3a13fbd4: Pulling fs layer
# b35c22f6a9bc: Pulling fs layer
# 8206ae2b86e3: Pulling fs layer
# 4f4fb700ef54: Pulling fs layer
# a9b2fba996c8: Pulling fs layer
# 57c8f95170d4: Pulling fs layer
# 217c82b1f15a: Pulling fs layer
# 973cc805e91c: Pulling fs layer
# c425ab4c2c48: Pulling fs layer
# aed13e0eac71: Pulling fs layer
# 8af440fcd8dd: Pulling fs layer
# dd95c6ad22f2: Pulling fs layer
# 4e6c4135d19b: Pulling fs layer
# 3d9b09ca1e5d: Pulling fs layer
# 2a6cb8fdb8cf: Pulling fs layer
# 9dd554f1f284: Pulling fs layer
# 111e3a13fbd4: Waiting
# b35c22f6a9bc: Waiting
# 8206ae2b86e3: Waiting
# 4f4fb700ef54: Waiting
# a9b2fba996c8: Waiting
# 57c8f95170d4: Waiting
# 217c82b1f15a: Waiting
# 973cc805e91c: Waiting
# c425ab4c2c48: Waiting
# aed13e0eac71: Waiting
# 8af440fcd8dd: Waiting
# dd95c6ad22f2: Waiting
# 4e6c4135d19b: Waiting
# 3d9b09ca1e5d: Waiting
# 2a6cb8fdb8cf: Waiting
# 9dd554f1f284: Waiting
# d47239a868b3: Verifying Checksum
# d47239a868b3: Download complete
# 49cbb10cca85: Verifying Checksum
# 49cbb10cca85: Download complete
# 111e3a13fbd4: Verifying Checksum
# 111e3a13fbd4: Download complete
# 6e0aa5e7af40: Verifying Checksum
# 6e0aa5e7af40: Download complete
# 4f4fb700ef54: Verifying Checksum
# 4f4fb700ef54: Download complete
# a9b2fba996c8: Verifying Checksum
# a9b2fba996c8: Download complete
# 8206ae2b86e3: Verifying Checksum
# 8206ae2b86e3: Download complete
# 217c82b1f15a: Verifying Checksum
# 217c82b1f15a: Download complete
# 973cc805e91c: Verifying Checksum
# 973cc805e91c: Download complete
# c425ab4c2c48: Verifying Checksum
# c425ab4c2c48: Download complete
# aed13e0eac71: Verifying Checksum
# aed13e0eac71: Download complete
# 8af440fcd8dd: Verifying Checksum
# 8af440fcd8dd: Download complete
# dd95c6ad22f2: Verifying Checksum
# dd95c6ad22f2: Download complete
# 4e6c4135d19b: Verifying Checksum
# 4e6c4135d19b: Download complete
# 57c8f95170d4: Verifying Checksum
# 57c8f95170d4: Download complete
# 3d9b09ca1e5d: Verifying Checksum
# 3d9b09ca1e5d: Download complete
# 9dd554f1f284: Verifying Checksum
# 9dd554f1f284: Download complete
# b35c22f6a9bc: Verifying Checksum
# b35c22f6a9bc: Download complete
# 6e0aa5e7af40: Pull complete
# d47239a868b3: Pull complete
# 49cbb10cca85: Pull complete
# 111e3a13fbd4: Pull complete
# 2a6cb8fdb8cf: Verifying Checksum
# 2a6cb8fdb8cf: Download complete
# b35c22f6a9bc: Pull complete
# 8206ae2b86e3: Pull complete
# 4f4fb700ef54: Pull complete
# a9b2fba996c8: Pull complete
# 57c8f95170d4: Pull complete
# 217c82b1f15a: Pull complete
# 973cc805e91c: Pull complete
# c425ab4c2c48: Pull complete
# aed13e0eac71: Pull complete
# 8af440fcd8dd: Pull complete
# dd95c6ad22f2: Pull complete
# 4e6c4135d19b: Pull complete
# 3d9b09ca1e5d: Pull complete
# 2a6cb8fdb8cf: Pull complete
# 9dd554f1f284: Pull complete
# Digest: sha256:8d72ecc97cd91b32cfc713ee0613d2cb73aff82c0f53abdd236ba24ec7b7e76c
# Status: Downloaded newer image for gcr.io/deeplearning-platform-release/base-cpu:latest
#  ---> 257fdd9e048b
# Step 2/5 : RUN pip install -U fire tensorflow==2.1.1
#  ---> Running in b5696ea8d334
# Collecting fire
#   Downloading fire-0.4.0.tar.gz (87 kB)
# Collecting tensorflow==2.1.1
#   Downloading tensorflow-2.1.1-cp37-cp37m-manylinux2010_x86_64.whl (421.8 MB)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting astor>=0.6.0
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Collecting google-pasta>=0.1.6
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.7/site-packages (from tensorflow==2.1.1) (0.36.2)
# Requirement already satisfied: wrapt>=1.11.1 in /opt/conda/lib/python3.7/site-packages (from tensorflow==2.1.1) (1.12.1)
# Collecting keras-preprocessing==1.1.0
#   Downloading Keras_Preprocessing-1.1.0-py2.py3-none-any.whl (41 kB)
# Requirement already satisfied: protobuf>=3.8.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==2.1.1) (3.15.8)
# Requirement already satisfied: grpcio>=1.8.6 in /opt/conda/lib/python3.7/site-packages (from tensorflow==2.1.1) (1.37.0)
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
# Collecting absl-py>=0.7.0
#   Downloading absl_py-0.12.0-py3-none-any.whl (129 kB)
# Collecting tensorboard<2.2.0,>=2.1.0
#   Downloading tensorboard-2.1.1-py3-none-any.whl (3.8 MB)
# Collecting tensorflow-estimator<2.2.0,>=2.1.0rc0
#   Downloading tensorflow_estimator-2.1.0-py2.py3-none-any.whl (448 kB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==2.1.1) (1.19.5)
# Collecting scipy==1.4.1
#   Downloading scipy-1.4.1-cp37-cp37m-manylinux1_x86_64.whl (26.1 MB)
# Collecting gast==0.2.2
#   Downloading gast-0.2.2.tar.gz (10 kB)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==2.1.1) (1.15.0)
# Collecting h5py
#   Downloading h5py-3.2.1-cp37-cp37m-manylinux1_x86_64.whl (4.1 MB)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/conda/lib/python3.7/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.1) (0.4.3)
# Collecting werkzeug>=0.11.15
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.7/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.1) (49.6.0.post20210108)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.7/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.1) (2.25.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /opt/conda/lib/python3.7/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.1) (1.28.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.7/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.1) (3.3.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.1) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.1) (4.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.1) (0.2.7)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.1) (1.3.0)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.1) (3.10.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.1) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.1) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.1) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.1) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.1) (2020.12.5)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.1) (3.0.1)
# Collecting cached-property
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->markdown>=2.6.8->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.1) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->markdown>=2.6.8->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.1) (3.7.4.3)
# Building wheels for collected packages: gast, termcolor, fire
#   Building wheel for gast (setup.py): started
#   Building wheel for gast (setup.py): finished with status 'done'
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7538 sha256=b49e9acf065e007e85bf0860b5d60d198d1bc4923d2adbd4c39447c33207ba92
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4829 sha256=b499052808ff1fc3cd2bb39e442bae40399692fb0e908671039b0e9fbe91875f
#   Stored in directory: /root/.cache/pip/wheels/3f/e3/ec/8a8336ff196023622fbcb36de0c5a5c218cbb24111d1d4c7f2
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115928 sha256=c6ff0e01f78ab5959f2546414402724070a1d235f33a41ab1f33e80bc19a35cf
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# Successfully built gast termcolor fire
# Installing collected packages: cached-property, werkzeug, h5py, absl-py, termcolor, tensorflow-estimator, tensorboard, scipy, opt-einsum, keras-preprocessing, keras-applications, google-pasta, gast, astor, tensorflow, fire
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.6.2
#     Uninstalling scipy-1.6.2:
#       Successfully uninstalled scipy-1.6.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# phik 0.11.2 requires scipy>=1.5.2, but you have scipy 1.4.1 which is incompatible.
# Successfully installed absl-py-0.12.0 astor-0.8.1 cached-property-1.5.2 fire-0.4.0 gast-0.2.2 google-pasta-0.2.0 h5py-3.2.1 keras-applications-1.0.8 keras-preprocessing-1.1.0 opt-einsum-3.3.0 scipy-1.4.1 tensorboard-2.1.1 tensorflow-2.1.1 tensorflow-estimator-2.1.0 termcolor-1.1.0 werkzeug-1.0.1
# Removing intermediate container b5696ea8d334
#  ---> 99c99c084d88
# Step 3/5 : WORKDIR /app
#  ---> Running in a6e937b74c43
# Removing intermediate container a6e937b74c43
#  ---> 33c93a680f98
# Step 4/5 : COPY train.py .
#  ---> 78f8b9a85d2e
# Step 5/5 : ENTRYPOINT ["python", "train.py"]
#  ---> Running in 902a125e632a
# Removing intermediate container 902a125e632a
#  ---> 910bfc8ddd82
# Successfully built 910bfc8ddd82
# Successfully tagged gcr.io/qwiklabs-gcp-04-248da7eb1719/tensorflow_trainer_image:latest
# PUSH
# Pushing gcr.io/qwiklabs-gcp-04-248da7eb1719/tensorflow_trainer_image:latest
# The push refers to repository [gcr.io/qwiklabs-gcp-04-248da7eb1719/tensorflow_trainer_image]
# e8274e7f0e80: Preparing
# 1b4cab315f81: Preparing
# 9f02fdfdfe5e: Preparing
# 06d47dc1550f: Preparing
# 6d0460e7b91d: Preparing
# 37a8adb4fafb: Preparing
# 25eacd11cb14: Preparing
# 8bc9ffacd92c: Preparing
# 640b32ec2e81: Preparing
# a803e99a9e4f: Preparing
# 6fd6ff343521: Preparing
# 889232675b1d: Preparing
# 037b4e8512b6: Preparing
# 15d726558b56: Preparing
# 1f2e24bbaee1: Preparing
# 5f70bf18a086: Preparing
# 31152d177e09: Preparing
# 3cec1b907843: Preparing
# dcc1b8729dd0: Preparing
# 6f15325cc380: Preparing
# 1e77dd81f9fa: Preparing
# 030309cad0ba: Preparing
# 37a8adb4fafb: Waiting
# 25eacd11cb14: Waiting
# 15d726558b56: Waiting
# 8bc9ffacd92c: Waiting
# 1f2e24bbaee1: Waiting
# 640b32ec2e81: Waiting
# 5f70bf18a086: Waiting
# 31152d177e09: Waiting
# a803e99a9e4f: Waiting
# 6fd6ff343521: Waiting
# 889232675b1d: Waiting
# 037b4e8512b6: Waiting
# 3cec1b907843: Waiting
# dcc1b8729dd0: Waiting
# 6f15325cc380: Waiting
# 1e77dd81f9fa: Waiting
# 030309cad0ba: Waiting
# 6d0460e7b91d: Layer already exists
# 06d47dc1550f: Layer already exists
# 37a8adb4fafb: Layer already exists
# 25eacd11cb14: Layer already exists
# 640b32ec2e81: Layer already exists
# 8bc9ffacd92c: Layer already exists
# a803e99a9e4f: Layer already exists
# 6fd6ff343521: Layer already exists
# 889232675b1d: Layer already exists
# 037b4e8512b6: Layer already exists
# 1f2e24bbaee1: Layer already exists
# 15d726558b56: Layer already exists
# 5f70bf18a086: Layer already exists
# 31152d177e09: Layer already exists
# dcc1b8729dd0: Layer already exists
# 3cec1b907843: Layer already exists
# 1e77dd81f9fa: Layer already exists
# 6f15325cc380: Layer already exists
# 030309cad0ba: Layer already exists
# e8274e7f0e80: Pushed
# 1b4cab315f81: Pushed
# 9f02fdfdfe5e: Pushed
# latest: digest: sha256:94d7556a8d5f93e8f76df245da755ecb44b3fad3cdb3a01b26d297b3afb3484f size: 4915
# DONE
# --------------------------------------------------------------------------------
#
# ID                                    CREATE_TIME                DURATION  SOURCE                                                                                                      IMAGES                                                                  STATUS
# 06997035-b98f-4bbb-99b4-f40f4f6757d3  2021-05-03T02:33:20+00:00  6M35S     gs://qwiklabs-gcp-04-248da7eb1719_cloudbuild/source/1620009200.269482-7082fba132be48568b3d281f83441400.tgz  gcr.io/qwiklabs-gcp-04-248da7eb1719/tensorflow_trainer_image (+1 more)  SUCCESS

# %% [markdown]
# ### Create PyTorch Training Script
# Two down, two to go! Now we will develop a PyTorch training script. We will use Pandas DataFrames combined with PyTorch's Dataset and Dataloader to ingest the data from CSVs, build a model with torch.nn, and write a training loop to train this model.

# %%
# !mkdir pytorch_trainer_image
# Out:
# mkdir: cannot create directory ‘pytorch_trainer_image’: File exists

# %%
# %%writefile ./pytorch_trainer_image/train.py

import os 
import subprocess
import datetime
import fire

import torch 
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import pandas as pd 
import numpy as np
from sklearn.preprocessing import StandardScaler

class TrainData(Dataset):
    def __init__(self, X_data, y_data):
        self.X_data = X_data
        self.y_data = y_data
        
    def __getitem__(self, index):
        return self.X_data[index], self.y_data[index]
        
    def __len__ (self):
        return len(self.X_data)
    
class BinaryClassifier(nn.Module):
    def __init__(self):
        super(BinaryClassifier, self).__init__()
        # 27 input features
        self.h1 = nn.Linear(27, 64) 
        self.h2 = nn.Linear(64, 64)
        self.output_layer = nn.Linear(64, 1) 
        
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=0.1)
        self.batchnorm1 = nn.BatchNorm1d(64)
        self.batchnorm2 = nn.BatchNorm1d(64)
        
    def forward(self, inputs):
        x = self.relu(self.h1(inputs))
        x = self.batchnorm1(x)
        x = self.relu(self.h2(x))
        x = self.batchnorm2(x)
        x = self.dropout(x)
        x = self.output_layer(x)
        
        return x

def binary_acc(y_pred, y_true):
    """Calculates accuracy"""
    y_pred_tag = torch.round(torch.sigmoid(y_pred))

    correct_results_sum = (y_pred_tag == y_true).sum().float()
    acc = correct_results_sum/y_true.shape[0]
    acc = torch.round(acc * 100)
    
    return acc

def train_evaluate(training_dataset_path, validation_dataset_path, batch_size, num_epochs, output_dir):
    
    batch_size = int(batch_size)
    num_epochs = int(num_epochs)
    
    # Read in train/validation data and concat 
    df_train = pd.read_csv(training_dataset_path)
    df_validation = pd.read_csv(validation_dataset_path)
    df = pd.concat([df_train, df_validation])

    categorical_features = ['workclass', 'occupation']
    target='income_bracket'

    # One-hot encode categorical variables 
    df = pd.get_dummies(df,columns=categorical_features)

    # Change label to 0 if <=50K, 1 if >50K
    df[target] = df[target].apply(lambda x: 0 if x==' <=50K' else 1)

    # Split features and labels into 2 different vars
    X_train = df.loc[:, df.columns != target]
    y_train = np.array(df[target])

    # Normalize features 
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)

    # Training data
    train_data = TrainData(torch.FloatTensor(X_train), 
                           torch.FloatTensor(y_train))

    # Use torch DataLoader to feed data to model 
    train_loader = DataLoader(dataset=train_data, batch_size=batch_size, drop_last=True)

    # Instantiate model 
    model = BinaryClassifier()
    
    # Loss is binary crossentropy w/ logits. Must manually implement sigmoid for inference
    criterion = nn.BCEWithLogitsLoss()
    
    # Adam optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    model.train()
    for e in range(1, num_epochs+1):
        epoch_loss = 0
        epoch_acc = 0
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()

            y_pred = model(X_batch)

            loss = criterion(y_pred, y_batch.unsqueeze(1))
            acc = binary_acc(y_pred, y_batch.unsqueeze(1))

            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
            epoch_acc += acc.item()


        print(f'Epoch {e}: Loss = {epoch_loss/len(train_loader):.5f} | Acc = {epoch_acc/len(train_loader):.3f}')

    # Save the model locally
    model_filename='model.pt'
    torch.save(model.state_dict(), model_filename)

    EXPORT_PATH = os.path.join(
        output_dir, datetime.datetime.now().strftime("%Y%m%d%H%M%S"))

    # Copy the model to GCS
    gcs_model_path = '{}/{}'.format(EXPORT_PATH, model_filename)
    subprocess.check_call(['gsutil', 'cp', model_filename, gcs_model_path])
    print('Saved model in: {}'.format(gcs_model_path))
    
if __name__ == '__main__':
    fire.Fire(train_evaluate)
# Out:
# Overwriting ./pytorch_trainer_image/train.py

# %% [markdown]
# ### Package PyTorch Training Script into a Docker Image
# Note the dependencies.

# %%
# %%writefile ./pytorch_trainer_image/Dockerfile
#
# FROM gcr.io/deeplearning-platform-release/base-cpu
# RUN pip install -U fire torch==1.6.0 scikit-learn==0.23.2 pandas==1.1.1
# WORKDIR /app
# COPY train.py .
#
# ENTRYPOINT ["python", "train.py"]
# Out:
# Overwriting ./pytorch_trainer_image/Dockerfile

# %% [markdown]
# ### Build the PyTorch Trainer Image
# Build and push the PyTorch training image to your project's Container Registry. Again, this will take a few minutes.

# %%
TORCH_IMAGE_NAME='pytorch_trainer_image'
TORCH_IMAGE_TAG='latest'
TORCH_IMAGE_URI='gcr.io/{}/{}:{}'.format(PROJECT_ID, TORCH_IMAGE_NAME, TORCH_IMAGE_TAG)

# %%
# !gcloud builds submit --tag $TORCH_IMAGE_URI $TORCH_IMAGE_NAME
# Out:
# Creating temporary tarball archive of 2 file(s) totalling 4.1 KiB before compression.
# Uploading tarball of [pytorch_trainer_image] to [gs://qwiklabs-gcp-04-248da7eb1719_cloudbuild/source/1620009600.886952-96c98f6e6085495d89c39cd1bc236c0d.tgz]
# Created [https://cloudbuild.googleapis.com/v1/projects/qwiklabs-gcp-04-248da7eb1719/locations/global/builds/0138a005-f996-4220-adc3-b3ab7686ee3d].
# Logs are available at [https://console.cloud.google.com/cloud-build/builds/0138a005-f996-4220-adc3-b3ab7686ee3d?project=551343526661].
# ----------------------------- REMOTE BUILD OUTPUT ------------------------------
# starting build "0138a005-f996-4220-adc3-b3ab7686ee3d"
#
# FETCHSOURCE
# Fetching storage object: gs://qwiklabs-gcp-04-248da7eb1719_cloudbuild/source/1620009600.886952-96c98f6e6085495d89c39cd1bc236c0d.tgz#1620009601184464
# Copying gs://qwiklabs-gcp-04-248da7eb1719_cloudbuild/source/1620009600.886952-96c98f6e6085495d89c39cd1bc236c0d.tgz#1620009601184464...
# / [1 files][  1.8 KiB/  1.8 KiB]
# Operation completed over 1 objects/1.8 KiB.
# BUILD
# Already have image (with digest): gcr.io/cloud-builders/docker
# Sending build context to Docker daemon  6.656kB
# Step 1/5 : FROM gcr.io/deeplearning-platform-release/base-cpu
# latest: Pulling from deeplearning-platform-release/base-cpu
# 6e0aa5e7af40: Pulling fs layer
# d47239a868b3: Pulling fs layer
# 49cbb10cca85: Pulling fs layer
# 111e3a13fbd4: Pulling fs layer
# b35c22f6a9bc: Pulling fs layer
# 8206ae2b86e3: Pulling fs layer
# 4f4fb700ef54: Pulling fs layer
# a9b2fba996c8: Pulling fs layer
# 57c8f95170d4: Pulling fs layer
# 217c82b1f15a: Pulling fs layer
# 973cc805e91c: Pulling fs layer
# c425ab4c2c48: Pulling fs layer
# aed13e0eac71: Pulling fs layer
# 8af440fcd8dd: Pulling fs layer
# dd95c6ad22f2: Pulling fs layer
# 4e6c4135d19b: Pulling fs layer
# 3d9b09ca1e5d: Pulling fs layer
# 2a6cb8fdb8cf: Pulling fs layer
# 9dd554f1f284: Pulling fs layer
# 111e3a13fbd4: Waiting
# b35c22f6a9bc: Waiting
# 8206ae2b86e3: Waiting
# 4f4fb700ef54: Waiting
# a9b2fba996c8: Waiting
# 57c8f95170d4: Waiting
# 217c82b1f15a: Waiting
# dd95c6ad22f2: Waiting
# 4e6c4135d19b: Waiting
# 3d9b09ca1e5d: Waiting
# 973cc805e91c: Waiting
# 2a6cb8fdb8cf: Waiting
# c425ab4c2c48: Waiting
# 9dd554f1f284: Waiting
# aed13e0eac71: Waiting
# 8af440fcd8dd: Waiting
# d47239a868b3: Verifying Checksum
# d47239a868b3: Download complete
# 49cbb10cca85: Verifying Checksum
# 49cbb10cca85: Download complete
# 111e3a13fbd4: Verifying Checksum
# 111e3a13fbd4: Download complete
# 6e0aa5e7af40: Verifying Checksum
# 6e0aa5e7af40: Download complete
# 4f4fb700ef54: Verifying Checksum
# 4f4fb700ef54: Download complete
# a9b2fba996c8: Verifying Checksum
# a9b2fba996c8: Download complete
# 8206ae2b86e3: Verifying Checksum
# 8206ae2b86e3: Download complete
# 217c82b1f15a: Verifying Checksum
# 217c82b1f15a: Download complete
# 973cc805e91c: Verifying Checksum
# 973cc805e91c: Download complete
# c425ab4c2c48: Verifying Checksum
# c425ab4c2c48: Download complete
# aed13e0eac71: Verifying Checksum
# aed13e0eac71: Download complete
# 8af440fcd8dd: Verifying Checksum
# 8af440fcd8dd: Download complete
# dd95c6ad22f2: Verifying Checksum
# dd95c6ad22f2: Download complete
# 4e6c4135d19b: Verifying Checksum
# 4e6c4135d19b: Download complete
# 3d9b09ca1e5d: Verifying Checksum
# 3d9b09ca1e5d: Download complete
# 57c8f95170d4: Verifying Checksum
# 57c8f95170d4: Download complete
# 9dd554f1f284: Verifying Checksum
# 9dd554f1f284: Download complete
# b35c22f6a9bc: Verifying Checksum
# b35c22f6a9bc: Download complete
# 6e0aa5e7af40: Pull complete
# d47239a868b3: Pull complete
# 49cbb10cca85: Pull complete
# 111e3a13fbd4: Pull complete
# 2a6cb8fdb8cf: Verifying Checksum
# 2a6cb8fdb8cf: Download complete
# b35c22f6a9bc: Pull complete
# 8206ae2b86e3: Pull complete
# 4f4fb700ef54: Pull complete
# a9b2fba996c8: Pull complete
# 57c8f95170d4: Pull complete
# 217c82b1f15a: Pull complete
# 973cc805e91c: Pull complete
# c425ab4c2c48: Pull complete
# aed13e0eac71: Pull complete
# 8af440fcd8dd: Pull complete
# dd95c6ad22f2: Pull complete
# 4e6c4135d19b: Pull complete
# 3d9b09ca1e5d: Pull complete
# 2a6cb8fdb8cf: Pull complete
# 9dd554f1f284: Pull complete
# Digest: sha256:8d72ecc97cd91b32cfc713ee0613d2cb73aff82c0f53abdd236ba24ec7b7e76c
# Status: Downloaded newer image for gcr.io/deeplearning-platform-release/base-cpu:latest
#  ---> 257fdd9e048b
# Step 2/5 : RUN pip install -U fire torch==1.6.0 scikit-learn==0.23.2 pandas==1.1.1
#  ---> Running in 7d50863972bc
# Collecting fire
#   Downloading fire-0.4.0.tar.gz (87 kB)
# Collecting torch==1.6.0
#   Downloading torch-1.6.0-cp37-cp37m-manylinux1_x86_64.whl (748.8 MB)
# Collecting scikit-learn==0.23.2
#   Downloading scikit_learn-0.23.2-cp37-cp37m-manylinux1_x86_64.whl (6.8 MB)
# Collecting pandas==1.1.1
#   Downloading pandas-1.1.1-cp37-cp37m-manylinux1_x86_64.whl (10.5 MB)
# Requirement already satisfied: numpy>=1.15.4 in /opt/conda/lib/python3.7/site-packages (from pandas==1.1.1) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas==1.1.1) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.7/site-packages (from pandas==1.1.1) (2021.1)
# Requirement already satisfied: scipy>=0.19.1 in /opt/conda/lib/python3.7/site-packages (from scikit-learn==0.23.2) (1.6.2)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from scikit-learn==0.23.2) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn==0.23.2) (2.1.0)
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas==1.1.1) (1.15.0)
# Collecting termcolor
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Building wheels for collected packages: fire, future, termcolor
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115928 sha256=4947b19d0a4da8f84cb460b18e7a33a412a3e5ab298619f05e9f97f554976a94
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491059 sha256=d87b9646f793c5f577d69d84f1d857f607c68a4c61475c850379888ae2354bb1
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4829 sha256=e556b3a8af7b2cf3c4cce9d384bdaf65c9a555ab51ab8f5da1cc5c65cee30717
#   Stored in directory: /root/.cache/pip/wheels/3f/e3/ec/8a8336ff196023622fbcb36de0c5a5c218cbb24111d1d4c7f2
# Successfully built fire future termcolor
# Installing collected packages: termcolor, future, torch, scikit-learn, pandas, fire
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.1
#     Uninstalling scikit-learn-0.24.1:
#       Successfully uninstalled scikit-learn-0.24.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.2.4
#     Uninstalling pandas-1.2.4:
#       Successfully uninstalled pandas-1.2.4
# Successfully installed fire-0.4.0 future-0.18.2 pandas-1.1.1 scikit-learn-0.23.2 termcolor-1.1.0 torch-1.6.0
# Removing intermediate container 7d50863972bc
#  ---> fcace47dd708
# Step 3/5 : WORKDIR /app
#  ---> Running in 154d6a0dec14
# Removing intermediate container 154d6a0dec14
#  ---> 31c34a3967a9
# Step 4/5 : COPY train.py .
#  ---> 1c1750b89816
# Step 5/5 : ENTRYPOINT ["python", "train.py"]
#  ---> Running in 68f7f1c7855d
# Removing intermediate container 68f7f1c7855d
#  ---> 9b21c1f83088
# Successfully built 9b21c1f83088
# Successfully tagged gcr.io/qwiklabs-gcp-04-248da7eb1719/pytorch_trainer_image:latest
# PUSH
# Pushing gcr.io/qwiklabs-gcp-04-248da7eb1719/pytorch_trainer_image:latest
# The push refers to repository [gcr.io/qwiklabs-gcp-04-248da7eb1719/pytorch_trainer_image]
# 4512758962d2: Preparing
# 3ec308852cd0: Preparing
# 0404d86cf490: Preparing
# 06d47dc1550f: Preparing
# 6d0460e7b91d: Preparing
# 37a8adb4fafb: Preparing
# 25eacd11cb14: Preparing
# 8bc9ffacd92c: Preparing
# 640b32ec2e81: Preparing
# a803e99a9e4f: Preparing
# 6fd6ff343521: Preparing
# 889232675b1d: Preparing
# 037b4e8512b6: Preparing
# 15d726558b56: Preparing
# 1f2e24bbaee1: Preparing
# 5f70bf18a086: Preparing
# 31152d177e09: Preparing
# 3cec1b907843: Preparing
# dcc1b8729dd0: Preparing
# 6f15325cc380: Preparing
# 1e77dd81f9fa: Preparing
# 030309cad0ba: Preparing
# 37a8adb4fafb: Waiting
# 15d726558b56: Waiting
# 1f2e24bbaee1: Waiting
# 5f70bf18a086: Waiting
# 31152d177e09: Waiting
# 3cec1b907843: Waiting
# dcc1b8729dd0: Waiting
# 6f15325cc380: Waiting
# 1e77dd81f9fa: Waiting
# 030309cad0ba: Waiting
# 6fd6ff343521: Waiting
# 25eacd11cb14: Waiting
# 889232675b1d: Waiting
# 037b4e8512b6: Waiting
# 8bc9ffacd92c: Waiting
# a803e99a9e4f: Waiting
# 640b32ec2e81: Waiting
# 06d47dc1550f: Layer already exists
# 6d0460e7b91d: Layer already exists
# 37a8adb4fafb: Layer already exists
# 25eacd11cb14: Layer already exists
# 640b32ec2e81: Layer already exists
# 8bc9ffacd92c: Layer already exists
# 6fd6ff343521: Layer already exists
# a803e99a9e4f: Layer already exists
# 037b4e8512b6: Layer already exists
# 889232675b1d: Layer already exists
# 1f2e24bbaee1: Layer already exists
# 15d726558b56: Layer already exists
# 5f70bf18a086: Layer already exists
# 31152d177e09: Layer already exists
# 3cec1b907843: Layer already exists
# dcc1b8729dd0: Layer already exists
# 6f15325cc380: Layer already exists
# 030309cad0ba: Layer already exists
# 1e77dd81f9fa: Layer already exists
# 4512758962d2: Pushed
# 3ec308852cd0: Pushed
# 0404d86cf490: Pushed
# latest: digest: sha256:e5a839bdfaab2c9f83e4fa5d8778bc9b0080b97f8439f71a6fae2eec1c8a649d size: 4916
# DONE
# --------------------------------------------------------------------------------
#
# ID                                    CREATE_TIME                DURATION  SOURCE                                                                                                      IMAGES                                                               STATUS
# 0138a005-f996-4220-adc3-b3ab7686ee3d  2021-05-03T02:40:01+00:00  7M39S     gs://qwiklabs-gcp-04-248da7eb1719_cloudbuild/source/1620009600.886952-96c98f6e6085495d89c39cd1bc236c0d.tgz  gcr.io/qwiklabs-gcp-04-248da7eb1719/pytorch_trainer_image (+1 more)  SUCCESS

# %% [markdown]
# ### Create XGBoost Training Script
# Three down, one to go! Create the final training script. This script will ingest and preprocess data with Pandas, then train a [Gradient Boosted Tree model](https://en.wikipedia.org/wiki/Gradient_boosting).

# %%
# !mkdir xgboost_trainer_image
# Out:
# mkdir: cannot create directory ‘xgboost_trainer_image’: File exists

# %%
# %%writefile ./xgboost_trainer_image/train.py

import os 
import subprocess
import datetime
import fire
import pickle 

import pandas as pd 
import numpy as np
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier

def train_evaluate(training_dataset_path, validation_dataset_path,max_depth,n_estimators,output_dir):
    
    df_train = pd.read_csv(training_dataset_path)
    df_validation = pd.read_csv(validation_dataset_path)
    df = pd.concat([df_train, df_validation])

    categorical_features = ['workclass', 'occupation']
    target='income_bracket'

    # One-hot encode categorical variables 
    df = pd.get_dummies(df,columns=categorical_features)

    # Change label to 0 if <=50K, 1 if >50K
    df[target] = df[target].apply(lambda x: 0 if x==' <=50K' else 1)

    # Split features and labels into 2 different vars
    X_train = df.loc[:, df.columns != target]
    y_train = np.array(df[target])

    # Normalize features 
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    
    grid = {
        'max_depth': int(max_depth),
        'n_estimators': int(n_estimators)
    }
    
    model = XGBClassifier()
    model.set_params(**grid)
    model.fit(X_train,y_train)
    
    model_filename = 'xgb_model.pkl'
    pickle.dump(model, open(model_filename, "wb"))
        
    EXPORT_PATH = os.path.join(
        output_dir, datetime.datetime.now().strftime("%Y%m%d%H%M%S"))
    
    gcs_model_path = '{}/{}'.format(EXPORT_PATH, model_filename)
    subprocess.check_call(['gsutil', 'cp', model_filename, gcs_model_path])
    print('Saved model in: {}'.format(gcs_model_path))  

if __name__ == '__main__':
    fire.Fire(train_evaluate)
# Out:
# Overwriting ./xgboost_trainer_image/train.py

# %% [markdown]
# ### Package XGBoost Training Script into a Docker Image
# Note the dependencies.

# %%
# %%writefile ./xgboost_trainer_image/Dockerfile
#
# FROM gcr.io/deeplearning-platform-release/base-cpu
# RUN pip install -U fire scikit-learn==0.23.2 pandas==1.1.1 xgboost==1.2.0
# WORKDIR /app
# COPY train.py .
#
# ENTRYPOINT ["python", "train.py"]
# Out:
# Overwriting ./xgboost_trainer_image/Dockerfile

# %% [markdown]
# ### Build the XGBoost Trainer Image
# Build and push the XGBoost training image. This will take a few minutes (this is the last one, woohoo!)

# %%
XGB_IMAGE_NAME='xgboost_trainer_image'
XGB_IMAGE_TAG='latest'
XGB_IMAGE_URI='gcr.io/{}/{}:{}'.format(PROJECT_ID, XGB_IMAGE_NAME, XGB_IMAGE_TAG)

# %%
# !gcloud builds submit --tag $XGB_IMAGE_URI $XGB_IMAGE_NAME
# Out:
# Creating temporary tarball archive of 2 file(s) totalling 1.8 KiB before compression.
# Uploading tarball of [xgboost_trainer_image] to [gs://qwiklabs-gcp-04-248da7eb1719_cloudbuild/source/1620010064.416005-2615bf9bb1c04493b31d6acf60635b5f.tgz]
# Created [https://cloudbuild.googleapis.com/v1/projects/qwiklabs-gcp-04-248da7eb1719/locations/global/builds/cb86e8e3-810f-47d8-bd92-e31be26451cb].
# Logs are available at [https://console.cloud.google.com/cloud-build/builds/cb86e8e3-810f-47d8-bd92-e31be26451cb?project=551343526661].
# ----------------------------- REMOTE BUILD OUTPUT ------------------------------
# starting build "cb86e8e3-810f-47d8-bd92-e31be26451cb"
#
# FETCHSOURCE
# Fetching storage object: gs://qwiklabs-gcp-04-248da7eb1719_cloudbuild/source/1620010064.416005-2615bf9bb1c04493b31d6acf60635b5f.tgz#1620010064766232
# Copying gs://qwiklabs-gcp-04-248da7eb1719_cloudbuild/source/1620010064.416005-2615bf9bb1c04493b31d6acf60635b5f.tgz#1620010064766232...
# / [1 files][  1.0 KiB/  1.0 KiB]
# Operation completed over 1 objects/1.0 KiB.
# BUILD
# Already have image (with digest): gcr.io/cloud-builders/docker
# Sending build context to Docker daemon  4.608kB
# Step 1/5 : FROM gcr.io/deeplearning-platform-release/base-cpu
# latest: Pulling from deeplearning-platform-release/base-cpu
# 6e0aa5e7af40: Pulling fs layer
# d47239a868b3: Pulling fs layer
# 49cbb10cca85: Pulling fs layer
# 111e3a13fbd4: Pulling fs layer
# b35c22f6a9bc: Pulling fs layer
# 8206ae2b86e3: Pulling fs layer
# 4f4fb700ef54: Pulling fs layer
# a9b2fba996c8: Pulling fs layer
# 57c8f95170d4: Pulling fs layer
# 217c82b1f15a: Pulling fs layer
# 973cc805e91c: Pulling fs layer
# c425ab4c2c48: Pulling fs layer
# aed13e0eac71: Pulling fs layer
# 8af440fcd8dd: Pulling fs layer
# dd95c6ad22f2: Pulling fs layer
# 4e6c4135d19b: Pulling fs layer
# 3d9b09ca1e5d: Pulling fs layer
# 2a6cb8fdb8cf: Pulling fs layer
# 9dd554f1f284: Pulling fs layer
# 111e3a13fbd4: Waiting
# b35c22f6a9bc: Waiting
# 8206ae2b86e3: Waiting
# 4f4fb700ef54: Waiting
# a9b2fba996c8: Waiting
# 57c8f95170d4: Waiting
# 217c82b1f15a: Waiting
# 973cc805e91c: Waiting
# c425ab4c2c48: Waiting
# aed13e0eac71: Waiting
# 8af440fcd8dd: Waiting
# dd95c6ad22f2: Waiting
# 4e6c4135d19b: Waiting
# 3d9b09ca1e5d: Waiting
# 2a6cb8fdb8cf: Waiting
# 9dd554f1f284: Waiting
# d47239a868b3: Verifying Checksum
# d47239a868b3: Download complete
# 49cbb10cca85: Download complete
# 111e3a13fbd4: Verifying Checksum
# 111e3a13fbd4: Download complete
# 6e0aa5e7af40: Verifying Checksum
# 6e0aa5e7af40: Download complete
# 4f4fb700ef54: Verifying Checksum
# 4f4fb700ef54: Download complete
# a9b2fba996c8: Verifying Checksum
# a9b2fba996c8: Download complete
# 8206ae2b86e3: Verifying Checksum
# 8206ae2b86e3: Download complete
# 217c82b1f15a: Verifying Checksum
# 217c82b1f15a: Download complete
# 973cc805e91c: Verifying Checksum
# 973cc805e91c: Download complete
# c425ab4c2c48: Verifying Checksum
# c425ab4c2c48: Download complete
# aed13e0eac71: Verifying Checksum
# aed13e0eac71: Download complete
# 8af440fcd8dd: Verifying Checksum
# 8af440fcd8dd: Download complete
# dd95c6ad22f2: Verifying Checksum
# dd95c6ad22f2: Download complete
# 57c8f95170d4: Verifying Checksum
# 57c8f95170d4: Download complete
# 4e6c4135d19b: Verifying Checksum
# 4e6c4135d19b: Download complete
# 3d9b09ca1e5d: Verifying Checksum
# 3d9b09ca1e5d: Download complete
# 9dd554f1f284: Verifying Checksum
# 9dd554f1f284: Download complete
# b35c22f6a9bc: Verifying Checksum
# b35c22f6a9bc: Download complete
# 6e0aa5e7af40: Pull complete
# d47239a868b3: Pull complete
# 49cbb10cca85: Pull complete
# 111e3a13fbd4: Pull complete
# 2a6cb8fdb8cf: Verifying Checksum
# 2a6cb8fdb8cf: Download complete
# b35c22f6a9bc: Pull complete
# 8206ae2b86e3: Pull complete
# 4f4fb700ef54: Pull complete
# a9b2fba996c8: Pull complete
# 57c8f95170d4: Pull complete
# 217c82b1f15a: Pull complete
# 973cc805e91c: Pull complete
# c425ab4c2c48: Pull complete
# aed13e0eac71: Pull complete
# 8af440fcd8dd: Pull complete
# dd95c6ad22f2: Pull complete
# 4e6c4135d19b: Pull complete
# 3d9b09ca1e5d: Pull complete
# 2a6cb8fdb8cf: Pull complete
# 9dd554f1f284: Pull complete
# Digest: sha256:8d72ecc97cd91b32cfc713ee0613d2cb73aff82c0f53abdd236ba24ec7b7e76c
# Status: Downloaded newer image for gcr.io/deeplearning-platform-release/base-cpu:latest
#  ---> 257fdd9e048b
# Step 2/5 : RUN pip install -U fire scikit-learn==0.23.2 pandas==1.1.1 xgboost==1.2.0
#  ---> Running in a44acc333ee3
# Collecting fire
#   Downloading fire-0.4.0.tar.gz (87 kB)
# Collecting scikit-learn==0.23.2
#   Downloading scikit_learn-0.23.2-cp37-cp37m-manylinux1_x86_64.whl (6.8 MB)
# Collecting pandas==1.1.1
#   Downloading pandas-1.1.1-cp37-cp37m-manylinux1_x86_64.whl (10.5 MB)
# Collecting xgboost==1.2.0
#   Downloading xgboost-1.2.0-py3-none-manylinux2010_x86_64.whl (148.9 MB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas==1.1.1) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in /opt/conda/lib/python3.7/site-packages (from pandas==1.1.1) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.7/site-packages (from pandas==1.1.1) (2021.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn==0.23.2) (2.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /opt/conda/lib/python3.7/site-packages (from scikit-learn==0.23.2) (1.6.2)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from scikit-learn==0.23.2) (1.0.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas==1.1.1) (1.15.0)
# Collecting termcolor
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Building wheels for collected packages: fire, termcolor
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115928 sha256=1e187f090f8ba7f0ac59a90021c5b113aa646d57b2ce96a67411b8bdb536e165
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4829 sha256=11157180a0205e2031282e43a4d445c80dbc4ec07e13f93516a2411c2847fc42
#   Stored in directory: /root/.cache/pip/wheels/3f/e3/ec/8a8336ff196023622fbcb36de0c5a5c218cbb24111d1d4c7f2
# Successfully built fire termcolor
# Installing collected packages: termcolor, xgboost, scikit-learn, pandas, fire
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.1
#     Uninstalling scikit-learn-0.24.1:
#       Successfully uninstalled scikit-learn-0.24.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.2.4
#     Uninstalling pandas-1.2.4:
#       Successfully uninstalled pandas-1.2.4
# Successfully installed fire-0.4.0 pandas-1.1.1 scikit-learn-0.23.2 termcolor-1.1.0 xgboost-1.2.0
# Removing intermediate container a44acc333ee3
#  ---> 0f61b9624564
# Step 3/5 : WORKDIR /app
#  ---> Running in 049889c8dae7
# Removing intermediate container 049889c8dae7
#  ---> af06e781e675
# Step 4/5 : COPY train.py .
#  ---> 4aa67ca4a262
# Step 5/5 : ENTRYPOINT ["python", "train.py"]
#  ---> Running in 73db7b06165c
# Removing intermediate container 73db7b06165c
#  ---> 9cf667add887
# Successfully built 9cf667add887
# Successfully tagged gcr.io/qwiklabs-gcp-04-248da7eb1719/xgboost_trainer_image:latest
# PUSH
# Pushing gcr.io/qwiklabs-gcp-04-248da7eb1719/xgboost_trainer_image:latest
# The push refers to repository [gcr.io/qwiklabs-gcp-04-248da7eb1719/xgboost_trainer_image]
# a347cd6d03b8: Preparing
# d7fefdf4e130: Preparing
# f9d82a3f38ed: Preparing
# 06d47dc1550f: Preparing
# 6d0460e7b91d: Preparing
# 37a8adb4fafb: Preparing
# 25eacd11cb14: Preparing
# 8bc9ffacd92c: Preparing
# 640b32ec2e81: Preparing
# a803e99a9e4f: Preparing
# 6fd6ff343521: Preparing
# 889232675b1d: Preparing
# 037b4e8512b6: Preparing
# 15d726558b56: Preparing
# 1f2e24bbaee1: Preparing
# 5f70bf18a086: Preparing
# 31152d177e09: Preparing
# 3cec1b907843: Preparing
# dcc1b8729dd0: Preparing
# 6f15325cc380: Preparing
# 1e77dd81f9fa: Preparing
# 030309cad0ba: Preparing
# 37a8adb4fafb: Waiting
# 25eacd11cb14: Waiting
# 640b32ec2e81: Waiting
# 8bc9ffacd92c: Waiting
# a803e99a9e4f: Waiting
# 5f70bf18a086: Waiting
# 6fd6ff343521: Waiting
# 889232675b1d: Waiting
# 037b4e8512b6: Waiting
# 15d726558b56: Waiting
# 1f2e24bbaee1: Waiting
# 31152d177e09: Waiting
# 3cec1b907843: Waiting
# dcc1b8729dd0: Waiting
# 6f15325cc380: Waiting
# 1e77dd81f9fa: Waiting
# 030309cad0ba: Waiting
# 6d0460e7b91d: Layer already exists
# 06d47dc1550f: Layer already exists
# 25eacd11cb14: Layer already exists
# 37a8adb4fafb: Layer already exists
# 8bc9ffacd92c: Layer already exists
# 640b32ec2e81: Layer already exists
# 6fd6ff343521: Layer already exists
# a803e99a9e4f: Layer already exists
# 889232675b1d: Layer already exists
# 037b4e8512b6: Layer already exists
# 1f2e24bbaee1: Layer already exists
# 15d726558b56: Layer already exists
# 31152d177e09: Layer already exists
# 5f70bf18a086: Layer already exists
# dcc1b8729dd0: Layer already exists
# 3cec1b907843: Layer already exists
# 6f15325cc380: Layer already exists
# 1e77dd81f9fa: Layer already exists
# 030309cad0ba: Layer already exists
# d7fefdf4e130: Pushed
# a347cd6d03b8: Pushed
# f9d82a3f38ed: Pushed
# latest: digest: sha256:0e3cca5ba983214a67cf6a4ce25a3f38b806129eaa4bf3df491a3afcd15d825f size: 4914
# DONE
# --------------------------------------------------------------------------------
#
# ID                                    CREATE_TIME                DURATION  SOURCE                                                                                                      IMAGES                                                               STATUS
# cb86e8e3-810f-47d8-bd92-e31be26451cb  2021-05-03T02:47:44+00:00  3M35S     gs://qwiklabs-gcp-04-248da7eb1719_cloudbuild/source/1620010064.416005-2615bf9bb1c04493b31d6acf60635b5f.tgz  gcr.io/qwiklabs-gcp-04-248da7eb1719/xgboost_trainer_image (+1 more)  SUCCESS

# %% [markdown]
# ## Develop KubeFlow Pipeline
# Now that you have all four of your training applications as containers in your project's Container Registry, let's build a KubeFlow pipeline.
#
# The KubeFlow pipeline will have two BigQuery Ops. We will use the pre-built BigQuery Query component (no need to reinvent the wheel) to do the following:
# * Create a training split in our data and export to CSV
# * Create a validation split in our data and export to CSV
#
# The output of these BigQuery Ops will be the input data into four AI Platform Training Ops. For this we will also use a pre-built component. Each AI Platform Training Op will train one of our containerized models - Tensorflow, PyTorch, XGBoost, and Scikit-learn.
#
# THERE ARE TODOs IN THE FOLLOWING CODE

# %%
# !mkdir pipeline
# Out:
# mkdir: cannot create directory ‘pipeline’: File exists

# %%
# %%writefile ./pipeline/census_training_pipeline.py

import os
import kfp
from kfp.dsl.types import GCPProjectID
from kfp.dsl.types import GCPRegion
from kfp.dsl.types import GCSPath
from kfp.dsl.types import String
from kfp.gcp import use_gcp_secret
import kfp.components as comp
import kfp.dsl as dsl
import kfp.gcp as gcp
import json

# We will use environment vars to set the trainer image names and bucket name
TF_TRAINER_IMAGE = os.getenv('TF_TRAINER_IMAGE')
SCIKIT_TRAINER_IMAGE = os.getenv('SCIKIT_TRAINER_IMAGE')
TORCH_TRAINER_IMAGE = os.getenv('TORCH_TRAINER_IMAGE')
XGB_TRAINER_IMAGE = os.getenv('XGB_TRAINER_IMAGE')
BUCKET = os.getenv('BUCKET')

# Paths to export the training/validation data from bigquery
TRAINING_OUTPUT_PATH = BUCKET + '/census/data/training.csv'
VALIDATION_OUTPUT_PATH = BUCKET + '/census/data/validation.csv'

COMPONENT_URL_SEARCH_PREFIX = 'https://raw.githubusercontent.com/kubeflow/pipelines/0.2.5/components/gcp/'

# Create component factories
component_store = kfp.components.ComponentStore(
    local_search_paths=None, url_search_prefixes=[COMPONENT_URL_SEARCH_PREFIX])

# Load BigQuery and AI Platform Training op
bigquery_query_op = component_store.load_component('bigquery/query')
mlengine_train_op = component_store.load_component('ml_engine/train')

def get_query(dataset='training'):
    """Function that returns either training or validation query"""
    if dataset=='training':
        split = "MOD(ABS(FARM_FINGERPRINT(CAST(functional_weight AS STRING))), 100) < 80"
    elif dataset=='validation':
        split = """MOD(ABS(FARM_FINGERPRINT(CAST(functional_weight AS STRING))), 100) >= 80 
        AND MOD(ABS(FARM_FINGERPRINT(CAST(functional_weight AS STRING))), 100) < 90"""
    else:
        split = "MOD(ABS(FARM_FINGERPRINT(CAST(functional_weight AS STRING))), 100) >= 90"
        
    query = """SELECT age, workclass, education_num, occupation, hours_per_week,income_bracket 
    FROM census.data 
    WHERE {0}""".format(split)
    
    return query

# We will use the training/validation queries as inputs to our pipeline
# This lets us change the training/validation datasets if we wish by simply
# Changing the query. 
TRAIN_QUERY = get_query(dataset='training')
VALIDATION_QUERY=get_query(dataset='validation')

@dsl.pipeline(
    name='Continuous Training with Multiple Frameworks',
    description='Pipeline to create training/validation splits w/ BigQuery then launch multiple AI Platform Training Jobs'
)
def pipeline(
    project_id,
    train_query=TRAIN_QUERY,
    validation_query=VALIDATION_QUERY,
    region='us-central1'
):
    # Creating the training data split
    create_training_split = bigquery_query_op(
        query=train_query,
        project_id=project_id,
        output_gcs_path=TRAINING_OUTPUT_PATH
    ).set_display_name('BQ Train Split')
    
    # Creating the validation data split
    create_validation_split = bigquery_query_op(
        query=validation_query,
        project_id=project_id,
        output_gcs_path=VALIDATION_OUTPUT_PATH
    ).set_display_name('BQ Eval Split')
    
    # These are the output directories where our models will be saved
    tf_output_dir = BUCKET + '/census/models/tf'
    scikit_output_dir = BUCKET + '/census/models/scikit'
    torch_output_dir = BUCKET + '/census/models/torch'
    xgb_output_dir = BUCKET + '/census/models/xgb'
    
    # Training arguments to be passed to the TF Trainer
    tf_args = [
        '--training_dataset_path', create_training_split.outputs['output_gcs_path'],
        '--validation_dataset_path', create_validation_split.outputs['output_gcs_path'],
        '--output_dir', tf_output_dir,
        '--batch_size', '32', 
        '--num_train_examples', '1000',
        '--num_evals', '10'
    ]
    
    # Training arguments to be passed to the Scikit-learn Trainer
    scikit_args = [
        '--training_dataset_path', create_training_split.outputs['output_gcs_path'],
        '--validation_dataset_path', create_validation_split.outputs['output_gcs_path'],
        '--output_dir', scikit_output_dir
    ]
    
    # Training arguments to be passed to the PyTorch Trainer
    torch_args = [
        '--training_dataset_path', create_training_split.outputs['output_gcs_path'],
        '--validation_dataset_path', create_validation_split.outputs['output_gcs_path'],
        '--output_dir', torch_output_dir,
        '--batch_size', '32', 
        '--num_epochs', '15',
    ]
    
    # Training arguments to be passed to the XGBoost Trainer 
    xgb_args = [
        '--training_dataset_path', create_training_split.outputs['output_gcs_path'],
        '--validation_dataset_path', create_validation_split.outputs['output_gcs_path'],
        '--output_dir', xgb_output_dir,
        '--max_depth', '10', 
        '--n_estimators', '100'
    ]
    
    # AI Platform Training Jobs with all 4 trainer images 
    
    train_scikit = mlengine_train_op(
        project_id=project_id,
        region=region,
        master_image_uri=SCIKIT_TRAINER_IMAGE,
        args=scikit_args).set_display_name('Scikit Model - AI Platform Training')
    
    train_tf = mlengine_train_op(
        project_id=project_id,
        region=region,
        master_image_uri=TF_TRAINER_IMAGE,
        args=tf_args).set_display_name('Tensorflow Model - AI Platform Training')
    
    train_torch = mlengine_train_op(
        project_id=project_id,
        region=region,
        master_image_uri=TORCH_TRAINER_IMAGE,
        args=torch_args).set_display_name('Pytorch Model - AI Platform Training')
    
    train_xgb = mlengine_train_op(
        project_id=project_id,
        region=region,
        master_image_uri=XGB_TRAINER_IMAGE,
        args=xgb_args).set_display_name('XGBoost Model - AI Platform Training')
# Out:
# Overwriting ./pipeline/census_training_pipeline.py

# %% [markdown]
# Set environment variables for the different trainer image names as well as our bucket.

# %%
TAG = 'latest'
SCIKIT_TRAINER_IMAGE = 'gcr.io/{}/scikit_trainer_image:{}'.format(PROJECT_ID, TAG)
TF_TRAINER_IMAGE = 'gcr.io/{}/tensorflow_trainer_image:{}'.format(PROJECT_ID, TAG)
TORCH_TRAINER_IMAGE = 'gcr.io/{}/pytorch_trainer_image:{}'.format(PROJECT_ID, TAG)
XGB_TRAINER_IMAGE = 'gcr.io/{}/xgboost_trainer_image:{}'.format(PROJECT_ID, TAG)

# %%
# %env TF_TRAINER_IMAGE={TF_TRAINER_IMAGE}
# %env SCIKIT_TRAINER_IMAGE={SCIKIT_TRAINER_IMAGE}
# %env TORCH_TRAINER_IMAGE={TORCH_TRAINER_IMAGE}
# %env XGB_TRAINER_IMAGE={XGB_TRAINER_IMAGE}
# %env BUCKET={BUCKET}
# Out:
# env: TF_TRAINER_IMAGE=gcr.io/qwiklabs-gcp-04-248da7eb1719/tensorflow_trainer_image:latest
# env: SCIKIT_TRAINER_IMAGE=gcr.io/qwiklabs-gcp-04-248da7eb1719/scikit_trainer_image:latest
# env: TORCH_TRAINER_IMAGE=gcr.io/qwiklabs-gcp-04-248da7eb1719/pytorch_trainer_image:latest
# env: XGB_TRAINER_IMAGE=gcr.io/qwiklabs-gcp-04-248da7eb1719/xgboost_trainer_image:latest
# env: BUCKET=gs://qwiklabs-gcp-04-248da7eb1719

# %% [markdown]
# ### Compile the Pipeline
# Compile the pipeline with the CLI compiler. This will save a census_training_pipeline.yaml file locally

# %%
# !dsl-compile --py pipeline/census_training_pipeline.py --output census_training_pipeline.yaml

# %% [markdown]
# ### Take a look at the head of the yaml file

# %%
# !head census_training_pipeline.yaml
# Out:
# "apiVersion": |-
#   argoproj.io/v1alpha1
# "kind": |-
#   Workflow
# "metadata":
#   "annotations":
#     "pipelines.kubeflow.org/pipeline_spec": |-
#       {"description": "Pipeline to create training/validation splits w/ BigQuery then launch multiple AI Platform Training Jobs", "inputs": [{"name": "project_id"}, {"default": "SELECT age, workclass, education_num, occupation, hours_per_week,income_bracket \n    FROM census.data \n    WHERE MOD(ABS(FARM_FINGERPRINT(CAST(functional_weight AS STRING))), 100) < 80", "name": "train_query", "optional": true}, {"default": "SELECT age, workclass, education_num, occupation, hours_per_week,income_bracket \n    FROM census.data \n    WHERE MOD(ABS(FARM_FINGERPRINT(CAST(functional_weight AS STRING))), 100) >= 80 \n        AND MOD(ABS(FARM_FINGERPRINT(CAST(functional_weight AS STRING))), 100) < 90", "name": "validation_query", "optional": true}, {"default": "us-central1", "name": "region", "optional": true}], "name": "Continuous Training with Multiple Frameworks"}
#   "generateName": |-
#     continuous-training-with-multiple-frameworks-

# %% [markdown]
# ### Deploy your KubeFlow Pipeline
# Now let's deploy the KubeFlow pipeline. Prior to the lab you should have spun up an AI Platform Pipelines Instance. In the AI Platform Pipeline UI click 'settings' on your pipeline and copy the endpoint. Paste the endpoint as the value for the string variable ENDPOINT.

# %%
#TODO: Change ENDPOINT to the ENDPOINT for your AI Platform Pipelines Instance

#client = kfp.Client(host='https://34091a4f3634ed17-dot-us-central2.pipelines.googleusercontent.com')
ENDPOINT = '34091a4f3634ed17-dot-us-central2.pipelines.googleusercontent.com'
PIPELINE_NAME = 'census_trainer_multiple_models'

# %%
# !kfp --endpoint $ENDPOINT pipeline upload \
-p $PIPELINE_NAME \
./census_training_pipeline.yaml
# Out:
# (500)
# Reason: Internal Server Error
# HTTP response headers: HTTPHeaderDict({'Content-Length': '1461', 'Content-Type': 'text/html; charset=utf-8', 'Date': 'Mon, 03 May 2021 02:51:26 GMT', 'Vary': 'Origin', 'X-Content-Type-Options': 'nosniff', 'X-Frame-Options': 'SAMEORIGIN', 'X-Powered-By': 'Express', 'X-Xss-Protection': '0', 'Set-Cookie': 'S=cloud_datalab_tunnel=Z_IM2n4vdcice3N9i8cCpyvGyqZ2u2HMBc-xuiGkHmc; Path=/; Max-Age=3600'})
# HTTP response body:
# <!DOCTYPE html>
# <html lang=en>
#   <meta charset=utf-8>
#   <meta name=viewport content="initial-scale=1, minimum-scale=1, width=device-width">
#   <title>Error 500 (Internal Server Error)!!1</title>
#   <style>
#     *{margin:0;padding:0}html,code{font:15px/22px arial,sans-serif}html{background:#fff;color:#222;padding:15px}body{margin:7% auto 0;max-width:390px;min-height:180px;padding:30px 0 15px}* > body{background:url(//www.google.com/images/errors/robot.png) 100% 5px no-repeat;padding-right:205px}p{margin:11px 0 22px;overflow:hidden}ins{color:#777;text-decoration:none}a img{border:0}@media screen and (max-width:772px){body{background:none;margin-top:0;max-width:none;padding-right:0}}#logo{background:url(//www.google.com/images/logos/errorpage/error_logo-150x54.png) no-repeat;margin-left:-5px}@media only screen and (min-resolution:192dpi){#logo{background:url(//www.google.com/images/logos/errorpage/error_logo-150x54-2x.png) no-repeat 0% 0%/100% 100%;-moz-border-image:url(//www.google.com/images/logos/errorpage/error_logo-150x54-2x.png) 0}}@media only screen and (-webkit-min-device-pixel-ratio:2){#logo{background:url(//www.google.com/images/logos/errorpage/error_logo-150x54-2x.png) no-repeat;-webkit-background-size:100% 100%}}#logo{display:inline-block;height:54px;width:150px}
#   </style>
#   <a href=//www.google.com/><span id=logo aria-label=Google></span></a>
#   <p><b>500.</b> <ins>That’s an error.</ins>
#   <p>  <ins>That’s all we know.</ins>

# %% [markdown]
# ### Continuous Training: Create Pipeline Run, then Create Recurring Runs in the UI.
# Now that we deployed our KubeFlow pipeline, let's head over to the UI and launch a pipeline run. You can either click **Open Pipelines Dashboard** in the AI Platform Pipeline UI or run the Python cell below and copy/paste the output into the browser. Once in the UI, complete the following steps:
# * Select **Pipelines** on the left-hand navigation panel
# * Select **census_trainer_multiple_models** then click **Create Run**
# * In the **Experiment** field select **Default**
# * For **Run Type** select **One-Off**
# * Enter your **Project ID** and hit **Start**. You can now monitor your pipeline run in the UI (it will take about **10 minutes** to complete the run).
#
# Now let's set up a recurring run:
# * Select **Pipelines** then **census_trainer_multiple_models** and click **Create Run**
# * In the **Experiement** field select **Default**
# * For **Run Type** select **Recurring**
# * Configure the Recurring Run to start tomorrow at 5pm and run once weekly
# * Enter your **Project ID** and hit **Start**
#
# Now your pipeline will run weekly starting tomorrow, it's as easy as that!

# %%
print(f"https://{ENDPOINT}")
# Out:
# https://34091a4f3634ed17-dot-us-central2.pipelines.googleusercontent.com

# %% [markdown]
# ### End of Lab, Congrats!
# In this lab you created containerized training applications for TensorFlow, PyTorch, Scikit-learn, an XGBoost models. You then created a KubeFlow pipeline that used pre built components to create training/validation splits in BigQuery data, export that data as CSV files to GCS, and launch AI Platform Training Jobs with the four containerized training applications. Finally, you ran the pipeline from the UI and set up Continuous Training to re-run your pipeline once a week!

# %%
o365
GWhx52Vt4MNp
